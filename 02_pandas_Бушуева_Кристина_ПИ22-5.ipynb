# %% [markdown]
# # Pandas

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ## Выполнила: Бушуева К.Н.
# __ПИ22-5__

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
import pandas as pd

recipes = pd.read_csv('recipes_sample.csv',delimiter = ',')
reviews = pd.read_csv('reviews_sample.csv',delimiter = ',')

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(f'recipes: {recipes.shape[0]} строк, {recipes.shape[1]} столбцов,', 'типы данных каждого столбца:',  f'{recipes.dtypes}', sep = '\n', end = '\n\n')
print(f'reviews: {reviews.shape[0]} строк, {reviews.shape[1]} столбцов,', f'типы данных каждого столбца:', f'{reviews.dtypes}', sep = '\n')
# Out:
# recipes: 30000 строк, 8 столбцов,
# типы данных каждого столбца:
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
#
# reviews: 126696 строк, 6 столбцов,
# типы данных каждого столбца:
# Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('Для recipes: ')
print(recipes.isna().sum()[recipes.isna().sum() != 0], end = '\n\n')
print(f'Доля строк, содержащая пропуски: {((recipes.shape[0] - recipes.dropna().shape[0])/recipes.shape[0]) * 100}%', end = '\n\n')

print('Для reviews: ')
print(reviews.isna().sum()[reviews.isna().sum() != 0], end = '\n\n')
print(f'Доля строк, содержащая пропуски: {((reviews.shape[0] - reviews.dropna().shape[0])/reviews.shape[0]) * 100}%')
# Out:
# Для recipes:
# n_steps          11190
# description        623
# n_ingredients     8880
# dtype: int64
#
# Доля строк, содержащая пропуски: 56.846666666666664%
#
# Для reviews:
# review    17
# dtype: int64
#
# Доля строк, содержащая пропуски: 0.013417945317926377%

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('Для recipes: ')
print(f'среднее значение для столбца minutes: {recipes["minutes"].mean(axis = 0)}', \
      f'среднее значение для столбца n_steps: {recipes["n_steps"].mean(axis = 0)}',\
      f'среднее значение для столбца n_ingredients: {recipes["n_ingredients"].mean(axis = 0)}', sep = '\n', end = '\n\n')
print('Для reviews: ')      
print(f'среднее значение для столбца rating: {reviews["rating"].mean(axis = 0)}')
# Out:
# Для recipes:
# среднее значение для столбца minutes: 123.35813333333333
# среднее значение для столбца n_steps: 9.805582137161085
# среднее значение для столбца n_ingredients: 9.008285984848484
#
# Для reviews:
# среднее значение для столбца rating: 4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes.sample(10)['name']
# Out:
# 2456     batter fried shark  from strictly business fis...
# 27660                          to die for maple pecan buns
# 4554                                    candy cane martini
# 1162                              artichoke onion frittata
# 24261                         simple raisin sauce  for ham
# 17121                       marvelous maple walnut granola
# 7107                                  citrus chili chicken
# 28812                      venison with plums and calvados
# 25077            spaghetti with eggplant  aubergine  sauce
# 22135          ranch steak bruschetta salad  cooking light
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews['Unnamed: 0'] = reviews.index
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id        date  rating  \
# 0                0       21752      57993  2003-05-01       5
# 1                1      431813     142201  2007-09-16       5
# 2                2      400708     252013  2008-01-10       4
# 3                3  2001852463     404716  2017-12-11       5
# 4                4       95810     129396  2008-03-14       5
# ...            ...         ...        ...         ...     ...
# 126691      126691     1270706     335534  2009-05-17       4
# 126692      126692     2282344       8701  2012-06-03       0
# 126693      126693      689540     222001  2008-04-08       5
# 126694      126694  2000242659     354979  2015-06-02       5
# 126695      126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes.submitted, format = '%Y/%m/%d')

recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %%
import numpy as np

recipes = pd.read_csv('recipes_sample.csv', delimiter = ',', parse_dates = ['submitted'])
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30000 non-null  object
#  1   id              30000 non-null  int64
#  2   minutes         30000 non-null  int64
#  3   contributor_id  30000 non-null  int64
#  4   submitted       30000 non-null  datetime64[ns]
#  5   n_steps         18810 non-null  float64
#  6   description     29377 non-null  object
#  7   n_ingredients   21120 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes.submitted.dt.year <= 2010]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = pd.Series(recipes['description']).str.len()

recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes.columns = recipes.columns.str.title()

recipes
# Out:
#                                                Name      Id  Minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        Contributor_Id  Submitted  N_Steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
lst = recipes['Name'].str.split(' ')

for i in lst.index:
    lst[i] = [wrd for wrd in lst[i] if wrd]
    lst[i] = len(lst[i])

recipes['name_word_count'] = pd.Series(lst)

recipes
# Out:
#                                                Name      Id  Minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        Contributor_Id  Submitted  N_Steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
counter = pd.DataFrame({'ID номер': list(recipes['Contributor_Id'].value_counts().index), \
                        'количество рецептов': list(recipes['Contributor_Id'].value_counts())})


print(f'Участник с ID номером {counter["ID номер"][0]} добавил наибольшее количество рецептов - {counter["количество рецептов"][0]}',\
      sep = '\n\n')

counter
# Out:
# Участник с ID номером 89831 добавил наибольшее количество рецептов - 421
#       ID номер  количество рецептов
# 0        89831                  421
# 1        37449                  346
# 2        37779                  345
# 3         1533                  186
# 4       169430                  183
# ...        ...                  ...
# 8399   1061628                    1
# 8400   1076183                    1
# 8401    429061                    1
# 8402     64032                    1
# 8403    186118                    1
#
# [8404 rows x 2 columns]

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
reviews.groupby(reviews['user_id'])['rating'].mean()
# Out:
# user_id
# 1533          4.761905
# 1535          4.356322
# 1634          3.714286
# 1676          5.000000
# 1792          4.333333
#                 ...
# 2002369279    5.000000
# 2002369442    2.000000
# 2002370317    5.000000
# 2002370666    0.000000
# 2002371792    4.000000
# Name: rating, Length: 44803, dtype: float64

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
counter2 = pd.DataFrame({'год': list(recipes['Submitted'].dt.year.value_counts().index), 'количество рецептов': list(recipes['Submitted'].dt.year.value_counts())})

counter2
# Out:
#      год  количество рецептов
# 0   2007                 4429
# 1   2008                 4029
# 2   2006                 3473
# 3   2005                 3130
# 4   2009                 2963
# 5   2002                 2644
# 6   2003                 2334
# 7   2004                 2153
# 8   2010                 1538
# 9   2011                  922
# 10  2012                  659
# 11  2001                  589
# 12  2013                  490
# 13  1999                  275
# 14  2014                  139
# 15  2000                  104
# 16  2015                   42
# 17  2017                   39
# 18  2016                   24
# 19  2018                   24

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
table = pd.concat((reviews, recipes), axis = 1)

# %%
zero_table = pd.DataFrame({'id': table['recipe_id'], 'name': table['Name'],\
                          'user_id': table['user_id'], 'rating': table['rating']})
zero_table
# Out:
#             id                                      name     user_id  rating
# 0        57993     george s at the cove  black bean soup       21752       5
# 1       142201        healthy for them  yogurt popsicles      431813       5
# 2       252013              i can t believe it s spinach      400708       4
# 3       404716                      italian  gut busters  2001852463       5
# 4       129396  love is in the air  beef fondue   sauces       95810       5
# ...        ...                                       ...         ...     ...
# 126691  335534                                       NaN     1270706       4
# 126692    8701                                       NaN     2282344       0
# 126693  222001                                       NaN      689540       5
# 126694  354979                                       NaN  2000242659       5
# 126695  415599                                       NaN      463435       5
#
# [126696 rows x 4 columns]

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
first_table = pd.DataFrame({'recipe_id': table['recipe_id'], 'name': table['Name'], \
                           'review_count': table.groupby(table['recipe_id'])['review'].count()}).dropna (subset=['recipe_id'])
first_table['review_count'] = first_table['review_count']. fillna (0)

first_table.loc[first_table['name'] == 'schnitz peach pie']
# Out:
#        recipe_id               name  review_count
# 23688    57993.0  schnitz peach pie           0.0

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
second_table = pd.DataFrame(table.groupby(table['Submitted'].dt.year)['rating'].mean()).sort_values(by = 'rating', axis=0)

print(second_table, end = '\n\n')
print(f'Рецепты, добавленные в {int(second_table.index[0])} году имеют наименьший средний рейтинг - {second_table["rating"].iloc[0]}')
# Out:
#              rating
# Submitted
# 2017.0     4.051282
# 2016.0     4.208333
# 2013.0     4.363265
# 2001.0     4.380306
# 2003.0     4.383462
# 2006.0     4.389577
# 2015.0     4.404762
# 2007.0     4.406864
# 2012.0     4.414264
# 2018.0     4.416667
# 2008.0     4.422189
# 2009.0     4.424232
# 2002.0     4.434569
# 2010.0     4.438231
# 2011.0     4.441432
# 2004.0     4.455643
# 2005.0     4.464856
# 1999.0     4.476364
# 2014.0     4.517986
# 2000.0     4.576923
#
# Рецепты, добавленные в 2017 году имеют наименьший средний рейтинг - 4.051282051282051

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
save_file = recipes.sort_values(by='name_word_count', ascending=False)
save_file.to_csv(r'3.1-3.3.csv', index= False)

save_file
# Out:
#                                                     Name      Id  Minutes  \
# 26223  subru uncle s whole green moong dal i ll be ma...   77188       95
# 28083  tsr version of t g i  friday s black bean soup...  102274       75
# 26222  subru uncle s toor ki dal sindhi style  dad  m...   76908       65
# 27876  top secret recipes version of  i h o p  griddl...  113346       20
# 5734   chicken curry or  cat s vomit on a bed of magg...  294898       30
# ...                                                  ...     ...      ...
# 3253                                          blackmoons  323195      430
# 4138                                         bushwhacker  156521       10
# 2357                                            basbousa   12957       60
# 15052                                          josefinas  264859       20
# 4710                                            caramels  143615       30
#
#        Contributor_Id  Submitted  N_Steps  \
# ...

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter(r'/Users/bshkrrr/Downloads/тод/лр2/Количество отзывов по рецептам.xlsx') as writer:
     first_table.to_excel(writer)

# %%
with pd.ExcelWriter(r'/Users/bshkrrr/Downloads/тод/лр2/Рецепты с оценками.xlsx') as writer:
     zero_table.to_excel(writer)
